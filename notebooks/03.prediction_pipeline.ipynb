# %%
import numpy as np
import pandas as pd
import re
import string

# %%
txt = 'they won the championship in football'

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation,'')
    return text

# %%
with open ('../static/model/corpora/stopwords/english', 'r')as file:
    sw = file.read().splitlines()

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
def preprocessing(text):
    data = pd.DataFrame([text], columns=['title'])
    data["title"] = data["title"].apply(lambda x: " ".join(x.lower() for x in x.split()))
    data["title"] = data["title"].apply(lambda x: " ".join(re.sub(r'^https?:\/\/.*[\r\n]*','', x, flags=re.MULTILINE) for x in x.split()))
    data["title"] = data["title"].apply(remove_punctuations)
    data["title"] = data["title"].str.replace('\d+', '', regex=True)
    data["title"] = data["title"].apply(lambda x: " ".join(x for x in x.split() if x not in sw))
    data["title"] = data["title"].apply(lambda x: " ".join(ps.stem(x)for x in x.split()))
    return data["title"]

# %%
preprocesssed_text = preprocessing(txt)

# %%
preprocesssed_text
# Out:
# 0    championship footbal
# Name: title, dtype: object

# %%
vocab = pd.read_csv('../static/model/vocabulary.txt',header=None)
tokens = vocab[0].tolist()

# %%
tokens
# Out:
# ['wall',
#  'st',
#  'bear',
#  'back',
#  'black',
#  'reuter',
#  'look',
#  'toward',
#  'commerci',
#  'aerospac',
#  'oil',
#  'economi',
#  'cloud',
#  'stock',
#  'outlook',
#  'iraq',
#  'halt',
#  'export',
#  'main',
#  'southern',
#  'pipelin',
#  'price',
#  'soar',
#  'alltim',
#  'record',
#  'pose',
#  'new',
#  'menac',
#  'us',
#  'afp',
#  'end',
#  'near',
#  'year',
#  'low',
#  'money',
#  'fund',
#  'fell',
#  'latest',
#  'week',
#  'ap',
#  'fed',
#  'minut',
#  'show',
#  'inflat',
#  'usatodaycom',
#  'safeti',
#  'net',
#  'forbescom',
#  'need',
#  'opec',
#  'pump',
#  'gov',
#  'nation',
#  'googl',
#  'ipo',
#  'auction',
#  'rocki',
#  'start',
#  'dollar',
#  'fall',
#  'trade',
#  'gap',
#  'rescu',
#  'old',
#  'saver',
#  'kid',
#  'rule',
#  'backtoschool',
#  'market',
#  'head',
#  'valu',
#  'deficit',
#  'swell',
#  'june',
#  'shell',
#  'could',
#  'target',
#  'total',
#  'face',
#  'playboy',
#  'eurozon',
#  'keep',
#  'grow',
#  'expans',
#  'slow',
#  'japan',
#  'shock',
#  'sa',
#  'rate',
#  'cut',
#  'car',
#  'across',
#  'board',
#  'south',
#  'korea',
#  'lower',
#  'interest',
#  'begin',
#  'friday',
#  'hp',
#  'share',
#  'tumbl',
#  'profit',
#  'news',
#  'textil',
#  'firm',
#  'job',
#  'chad',
#  'seek',
#  'refuge',
#  'aid',
#  'imf',
#  'nuclear',
#  'shut',
#  'plant',
#  'veteran',
#  'inventor',
#  'float',
#  'saudi',
#  'arabia',
#  'open',
#  'tap',
#  'phone',
#  'sector',
#  'get',
#  'bn',
#  'lift',
#  'indian',
#  'fill',
#  'rail',
#  'skill',
#  'shortag',
#  'steadi',
#  'go',
#  'type',
#  'confus',
#  'bargain',
#  'hunter',
#  'research',
#  'email',
#  'microsoft',
#  'corp',
#  'corpor',
#  'cultur',
#  'letter',
#  'gloom',
#  'technolog',
#  'compani',
#  'sue',
#  'five',
#  'grant',
#  'central',
#  'squar',
#  'state',
#  'bank',
#  'give',
#  'k',
#  'legal',
#  'chapter',
#  'russia',
#  'flex',
#  'muscl',
#  'switch',
#  'titl',
#  'gear',
#  'dell',
#  'sale',
#  'ultim',
#  'statu',
#  'symbol',
#  'qualiti',
#  'away',
#  'make',
#  'insur',
#  'pay',
#  'delight',
#  'chrysler',
#  'king',
#  'what',
#  'cool',
#  'pool',
#  'hot',
#  'deck',
#  'age',
#  'doom',
#  'hip',
#  'onlin',
#  'shop',
#  'stoke',
#  'come',
#  'custom',
#  'town',
#  'barrel',
#  'monkey',
#  'edit',
#  'note',
#  'philippin',
#  'elect',
#  'final',
#  'park',
#  'lot',
#  'white',
#  'man',
#  'asian',
#  'minor',
#  'affirm',
#  'action',
#  'quest',
#  'work',
#  'blue',
#  'life',
#  'path',
#  'heartbreak',
#  'song',
#  'real',
#  'time',
#  'modern',
#  'bill',
#  'meet',
#  'water',
#  'best',
#  'tourism',
#  'destin',
#  'citi',
#  'busi',
#  'asia',
#  'tale',
#  'project',
#  'fail',
#  'bea',
#  'grab',
#  'ca',
#  'exec',
#  'product',
#  'group',
#  'tackl',
#  'collabor',
#  'uk',
#  'nh',
#  'gartner',
#  'help',
#  'plan',
#  'b',
#  'overhaul',
#  'play',
#  'boy',
#  'big',
#  'dutch',
#  'beat',
#  'appl',
#  'punch',
#  'buy',
#  'person',
#  'oper',
#  'verizon',
#  'paid',
#  'search',
#  'growth',
#  'may',
#  'sell',
#  'franc',
#  'surrend',
#  'madden',
#  'espn',
#  'footbal',
#  'score',
#  'differ',
#  'way',
#  'propos',
#  'highspe',
#  'wireless',
#  'format',
#  'aol',
#  'cheap',
#  'pc',
#  'senior',
#  'approv',
#  'disc',
#  'miss',
#  'deal',
#  'return',
#  'softwar',
#  'co',
#  'hacker',
#  'crack',
#  'stream',
#  'european',
#  'download',
#  'servic',
#  'mobil',
#  'sourc',
#  'app',
#  'develop',
#  'releas',
#  'techweb',
#  'oracl',
#  'data',
#  'seen',
#  'sun',
#  'glass',
#  'provid',
#  'view',
#  'world',
#  'second',
#  'japanes',
#  'retail',
#  'store',
#  'month',
#  'maccentr',
#  'charley',
#  'forc',
#  'took',
#  'expert',
#  'surpris',
#  'scienc',
#  'polit',
#  'collid',
#  'build',
#  'dedic',
#  'columbia',
#  'astronaut',
#  'russian',
#  'cargo',
#  'craft',
#  'dock',
#  'space',
#  'station',
#  'bangkok',
#  'lose',
#  'urban',
#  'rex',
#  'teen',
#  'spurt',
#  'scientist',
#  'say',
#  'gene',
#  'turn',
#  'studi',
#  'dolphin',
#  'born',
#  'name',
#  'well',
#  'matt',
#  'paul',
#  'allow',
#  'clone',
#  'human',
#  'embryo',
#  'alien',
#  'spaceship',
#  'claim',
#  'rais',
#  'skeptic',
#  'spacecom',
#  'comet',
#  'asteroid',
#  'planet',
#  'around',
#  'star',
#  'meteor',
#  'shower',
#  'peak',
#  'overnight',
#  'rocket',
#  'nasa',
#  'find',
#  'home',
#  'rat',
#  'hook',
#  'drug',
#  'chief',
#  'let',
#  'save',
#  'hubbl',
#  'x',
#  'prize',
#  'prototyp',
#  'crash',
#  'dog',
#  'wont',
#  'endang',
#  'list',
#  'troubl',
#  'one',
#  'four',
#  'instrument',
#  'stop',
#  'invas',
#  'match',
#  'supercomput',
#  'shuttl',
#  'engin',
#  'ant',
#  'form',
#  'mile',
#  'viewer',
#  'guid',
#  'aug',
#  'rescuer',
#  'free',
#  'beach',
#  'whale',
#  'brazil',
#  'falcon',
#  'sight',
#  'mass',
#  'weak',
#  'version',
#  'power',
#  'explos',
#  'found',
#  'tropic',
#  'storm',
#  'genesi',
#  'spacecraft',
#  'adjust',
#  'cours',
#  'earth',
#  'rare',
#  'suggest',
#  'probe',
#  'pacif',
#  'dead',
#  'zone',
#  'mar',
#  'like',
#  'india',
#  'rethink',
#  'send',
#  'moon',
#  'natur',
#  'dim',
#  'strang',
#  'websit',
#  'user',
#  'scout',
#  'red',
#  'appeal',
#  'reject',
#  'restor',
#  'explor',
#  'mani',
#  'color',
#  'britain',
#  'licens',
#  'next',
#  'great',
#  'race',
#  'spaceshipon',
#  'wild',
#  'fire',
#  'gold',
#  'pioneer',
#  'van',
#  'allen',
#  'question',
#  'spaceflight',
#  'china',
#  'flight',
#  'countdown',
#  'size',
#  'lunar',
#  'delay',
#  'pollut',
#  'appear',
#  'east',
#  'coast',
#  'vietnam',
#  'vulner',
#  'weather',
#  'bar',
#  'weaken',
#  'canadian',
#  'robot',
#  'candid',
#  'cave',
#  'discov',
#  'pit',
#  'croatia',
#  'review',
#  'death',
#  'better',
#  'measur',
#  'rain',
#  'wash',
#  'team',
#  'privat',
#  'explod',
#  'nevada',
#  'ponder',
#  'mine',
#  'indict',
#  'use',
#  'dna',
#  'rise',
#  'southeast',
#  'see',
#  'fewer',
#  'turtl',
#  'nest',
#  'said',
#  'readi',
#  'pet',
#  'put',
#  'ocean',
#  'floor',
#  'reach',
#  'virginia',
#  'expedit',
#  'gulf',
#  'mexico',
#  'accus',
#  'impact',
#  'method',
#  'predict',
#  'quak',
#  'ahead',
#  'marin',
#  'speci',
#  'annual',
#  'closur',
#  'el',
#  'cassini',
#  'saturn',
#  'lightn',
#  'rhino',
#  'risk',
#  'downplay',
#  'texa',
#  'shark',
#  'attack',
#  'bird',
#  'feed',
#  'young',
#  'join',
#  'launch',
#  'contest',
#  'univers',
#  'largest',
#  'telescop',
#  'capit',
#  'battl',
#  'locust',
#  'swarm',
#  'privaci',
#  'breach',
#  'mozilla',
#  'add',
#  'support',
#  'junk',
#  'fax',
#  'quot',
#  'visual',
#  'strike',
#  'fighter',
#  'american',
#  'feel',
#  'recoveri',
#  'reflect',
#  'system',
#  'properti',
#  'thank',
#  'ibm',
#  'id',
#  'blog',
#  'machin',
#  'pretti',
#  'bin',
#  'laden',
#  'associ',
#  'except',
#  'ron',
#  'jr',
#  'guy',
#  'al',
#  'qaeda',
#  'member',
#  'mission',
#  'half',
#  'right',
#  'revers',
#  'kerri',
#  'ad',
#  'would',
#  'babi',
#  'think',
#  'freedom',
#  'window',
#  'isnt',
#  'unix',
#  'ie',
#  'drm',
#  'good',
#  'congress',
#  'advis',
#  'adapt',
#  'enterpris',
#  'cant',
#  'reader',
#  'pledg',
#  'antipiraci',
#  'speed',
#  'boost',
#  'watchdog',
#  'broadband',
#  'win',
#  'take',
#  'sp',
#  'sharer',
#  'hit',
#  'briton',
#  'embrac',
#  'digit',
#  'lifestyl',
#  'playstat',
#  'potenti',
#  'learn',
#  'olymp',
#  'satellit',
#  'secur',
#  'video',
#  'game',
#  'children',
#  'fake',
#  'tempt',
#  'adult',
#  'far',
#  'perfect',
#  'introduc',
#  'cheaper',
#  'upgrad',
#  'pictur',
#  'yahoo',
#  'settl',
#  'patent',
#  'disput',
#  'doctor',
#  'treat',
#  'comput',
#  'must',
#  'xp',
#  'stamp',
#  'parcel',
#  'internet',
#  'challeng',
#  'forecast',
#  'plenti',
#  'activ',
#  'front',
#  'bid',
#  'place',
#  'despit',
#  'mix',
#  'antitrust',
#  'lawyer',
#  'helm',
#  'ftc',
#  'call',
#  'heavi',
#  'transport',
#  'lawsuit',
#  'execut',
#  'son',
#  'ebay',
#  'stake',
#  'craigslist',
#  'hungri',
#  'eat',
#  'less',
#  'hope',
#  'plane',
#  'arctic',
#  'camera',
#  'watch',
#  'fuel',
#  'tank',
#  'bubbl',
#  'coral',
#  'orang',
#  'glow',
#  'close',
#  'museum',
#  'dash',
#  'worm',
#  'stem',
#  'cell',
#  'test',
#  'slash',
#  'infect',
#  'given',
#  'goahead',
#  'damag',
#  'reserv',
#  'heat',
#  'wave',
#  'set',
#  'becom',
#  'brutal',
#  'hear',
#  'clue',
#  'evolut',
#  'extend',
#  'hurrican',
#  'season',
#  'climat',
#  'chang',
#  'alaska',
#  'strongli',
#  'influenc',
#  'england',
#  'forest',
#  'greater',
#  'air',
#  'warmer',
#  'interact',
#  'duke',
#  'idea',
#  'tree',
#  'reloc',
#  'quickli',
#  'respons',
#  'drought',
#  'dust',
#  'bowl',
#  'investig',
#  'reef',
#  'hazard',
#  'typhoon',
#  'spin',
#  'brain',
#  'buzz',
#  'left',
#  'voyag',
#  'prepar',
#  'gain',
#  'pound',
#  'day',
#  'fossil',
#  'evolv',
#  'seat',
#  'balloon',
#  'unusu',
#  'expect',
#  'tonight',
#  'monster',
#  'common',
#  'ancient',
#  'olympian',
#  'follow',
#  'atkin',
#  'diet',
#  'scholar',
#  'warrior',
#  'arm',
#  'african',
#  'hunt',
#  'sudanes',
#  'sport',
#  'parti',
#  'travel',
#  'column',
#  'offset',
#  'greenhous',
#  'surg',
#  'move',
#  'mountain',
#  'lab',
#  'adopt',
#  'florida',
#  'refug',
#  'inspir',
#  'prevent',
#  'progress',
#  'suppli',
#  'ship',
#  'experiment',
#  'hospit',
#  'fool',
#  'catch',
#  'earli',
#  'phase',
#  'cosmic',
#  'assembl',
#  'insid',
#  'titan',
#  'laboratori',
#  'imag',
#  'ever',
#  'disk',
#  'reveal',
#  'sign',
#  'celebr',
#  'scientif',
#  'breakthrough',
#  'cluster',
#  'galaxi',
#  'giant',
#  'ga',
#  'edg',
#  'magnet',
#  'knock',
#  'heaven',
#  'door',
#  'bring',
#  'closer',
#  'iss',
#  'repair',
#  'made',
#  'die',
#  'goe',
#  'ring',
#  'lost',
#  'sleep',
#  'lead',
#  'health',
#  'problem',
#  'smoke',
#  'last',
#  'flu',
#  'shot',
#  'effect',
#  'couch',
#  'potato',
#  'offer',
#  'tough',
#  'unravel',
#  'addict',
#  'mysteri',
#  'sting',
#  'bug',
#  'bite',
#  'linger',
#  'fda',
#  'warn',
#  'terrorist',
#  'prescript',
#  'fear',
#  'surgeri',
#  'detail',
#  'live',
#  'eye',
#  'vaccin',
#  'promis',
#  'first',
#  'ladi',
#  'john',
#  'pro',
#  'stanc',
#  'devic',
#  'room',
#  'healthi',
#  'beyond',
#  'thing',
#  'tech',
#  'rebound',
#  'pinch',
#  'briefli',
#  'partner',
#  'g',
#  'maker',
#  'judg',
#  'document',
#  'case',
#  'worker',
#  'optimist',
#  'california',
#  'urg',
#  'voip',
#  'steer',
#  'expand',
#  'midmarket',
#  'ambit',
#  'earn',
#  'alert',
#  'revenu',
#  'amid',
#  'turmoil',
#  'amd',
#  'nanomet',
#  'chip',
#  'lenovo',
#  'persist',
#  'secondquart',
#  'soft',
#  'woe',
#  'kind',
#  'replac',
#  'three',
#  'boss',
#  'mainfram',
#  'momentum',
#  'continu',
#  'gateway',
#  'easier',
#  'athen',
#  'itun',
#  'tout',
#  'sender',
#  'fight',
#  'spam',
#  'scam',
#  'beg',
#  'blast',
#  'past',
#  'suspect',
#  'plead',
#  'guilti',
#  'plug',
#  'hole',
#  'exchang',
#  'flaw',
#  'chat',
#  'intrud',
#  'cox',
#  'leav',
#  'behind',
#  'nortel',
#  'contract',
#  'smart',
#  'vonag',
#  'hang',
#  'caller',
#  'faster',
#  'wifi',
#  'specif',
#  'block',
#  'tri',
#  'run',
#  'fcc',
#  'freescal',
#  'push',
#  'talk',
#  'palmsourc',
#  'chairman',
#  'step',
#  'bluray',
#  'spec',
#  'ipod',
#  'chipmak',
#  'soni',
#  'zoom',
#  'tv',
#  'palmon',
#  'tool',
#  'want',
#  'improv',
#  'dvd',
#  'player',
#  'sharp',
#  'without',
#  'funni',
#  'report',
#  'lo',
#  'alamo',
#  'hardwar',
#  'inventori',
#  'circuit',
#  'choos',
#  'linux',
#  'cash',
#  'regist',
#  'train',
#  'counter',
#  'offshor',
#  'ground',
#  'cost',
#  'concern',
#  'requir',
#  'advanc',
#  'q',
#  'full',
#  'swing',
#  'wrap',
#  'traction',
#  'storag',
#  'server',
#  'result',
#  'doesnt',
#  'cover',
#  'sm',
#  'resign',
#  'updat',
#  'demand',
#  'firewal',
#  'newest',
#  'expos',
#  'trojan',
#  'symbian',
#  'ati',
#  'msn',
#  'movi',
#  'rental',
#  'quiet',
#  'line',
#  'carri',
#  'virtual',
#  'author',
#  'intern',
#  'intel',
#  'antispam',
#  ...]

# %%
def vectorizer(ds, vocabulary):
    vectorized_list = []

    for sentence in ds:
        sentence_list = np.zeros(len(vocabulary))

        for i in range(len(vocabulary)):
            if vocabulary[i] in sentence.split():
                sentence_list[i]=1

        vectorized_list.append(sentence_list)

    vectorized_list_new = np.asarray(vectorized_list, dtype=np.float32)

    return vectorized_list_new

# %%
def get_prediction(vectorized_txt):
    prediction = model.predict(vectorized_txt)
    if prediction == 1:
        return 'world'
    elif prediction == 2:
        return 'sports'
    elif prediction == 3:
        return 'business'
    elif prediction == 4:
        return 'science & technology'

# %%
vectorized_txt = vectorizer(preprocesssed_text, tokens)

# %%
vectorized_txt
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32)

# %%
import pickle

# %%
with open('../static/model/model.pickle', 'rb') as f:
    model = pickle.load(f)

# %%
prediction = get_prediction(vectorized_txt)

# %%
prediction
# Out:
# 'sports'
